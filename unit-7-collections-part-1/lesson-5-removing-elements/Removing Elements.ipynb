# %% [markdown]
# # Removing Elements

# %% [markdown]
# ### Remove by element

# %%
shopping_list = ['Milk', 'Eggs', 'Bread']

shopping_list.remove('Eggs')

print(shopping_list)
# Out:
# ['Milk', 'Bread']

# %% [markdown]
# (watch out for repeated elements)

# %%
my_list = ['a', 'b', 'c', 'b', 'b']

my_list.remove('b')  # There are three 'b's in this list.

print(my_list)
# Out:
# ['a', 'c', 'b', 'b']

# %% [markdown]
# ### Remove by position

# %%
my_list = ['a', 'b', 'c', 'd']

# Remove from the beginning
my_list.pop(0)

print(my_list)
# Out:
# ['b', 'c', 'd']

# %%
my_list.pop(1)
print(my_list)
# Out:
# ['a', 'c', 'd']

# %%
my_list.pop(9)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-d68e31008fe7> in <module>()
# ----> 1 my_list.pop(9)
#
# IndexError: pop index out of range

# %% [markdown]
# ### Remove the last element

# %%
my_list = ['a', 'b', 'c', 'd']
